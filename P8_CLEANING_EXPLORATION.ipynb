# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn
import ast
from scipy import stats

# %%
df_effective_args = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/P8/dataset/train.csv',encoding="utf-8",header=(0))

# %%
df_effective_args
# Out:
#        discourse_id      essay_id  \
# 0      0013cc385424  007ACE74B050
# 1      9704a709b505  007ACE74B050
# 2      c22adee811b6  007ACE74B050
# 3      a10d361e54e4  007ACE74B050
# 4      db3e453ec4e2  007ACE74B050
# ...             ...           ...
# 36760  9f63b687e76a  FFA381E58FC6
# 36761  9d5bd7d86212  FFA381E58FC6
# 36762  f1b78becd573  FFA381E58FC6
# 36763  cc184624ca8e  FFA381E58FC6
# 36764  c8a973681feb  FFA381E58FC6
#
#                                           discourse_text  \
# 0      Hi, i'm Isaac, i'm going to be writing about h...
# 1      On my perspective, I think that the face is a ...
# 2      I think that the face is a natural landform be...
# 3      If life was on Mars, we would know by now. The...
# 4      People thought that the face was formed by ali...
# ...                                                  ...
# 36760  For many people they don't like only asking on...
# 36761  also people have different views and opinions ...
# ...

# %% [markdown]
# # Nettoyage : Recherche de doublon

# %%
df_duplicates = df_effective_args[df_effective_args.duplicated(subset=['discourse_text'], keep=False)]

# %% [markdown]
# Parmi le tableau de 119 lignes ci dessus, il y a des doublons

# %%
df_duplicates_with_different_effectiveness = df_duplicates[~df_duplicates.duplicated(subset=['discourse_text', 'discourse_effectiveness'], keep=False)]

# %%
df_duplicates_with_different_effectiveness
# Out:
#        discourse_id      essay_id  \
# 2976   d95e0de29b68  3713AC622BFF
# 4461   3c850f2249c7  4FAC3B29417F
# 5483   2ac5a02e11ee  648987861269
# 5621   bc32caccb339  66CE6C9D0594
# 6570   dee3f8aec4fc  7742D58270C9
# 11100  bedb68b0c6ee  C7FA88E9DF3B
# 11114  acb9f8d7e741  C8126FF37E55
# 11970  cc0dad1234ec  D8013F49DE51
# 18623  d258208bc946  38F0C2290179
# 20121  35bf70c4a673  4CA37D113612
# 20842  34b98386dc46  5729D5AE055C
# 21785  ac4a6fb163a3  643B41BE89EE
# 28406  98154af4855d  BACC53ECC1FB
# 28436  9e12ec699196  BB3A6C2D0B65
# 31753  b318a4e3b80e  EE2FC4219F49
# 31757  43848fd5dfb3  EE2FC4219F49
# 33794  5a8b56c597d3  331CA007D0AD
# 35299  608e1d81f4ed  9627B47C10DE
# 35488  bcdb6e47ede3  AB8EFBD82820
# 35493  98510222f9b8  AB8EFBD82820
# 35973  9b72380e4fc2  C8FB2508978A
# 36587  391e3628a1f5  F52B9A0882BB
#
#                                           discourse_text discourse_type  \
# 2976   The author suggest that studying Venus is a wo...       Position
# ...
